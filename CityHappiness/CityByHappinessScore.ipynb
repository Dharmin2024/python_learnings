# %%
import pandas as pd

# %%
df= pd.read_csv('/Users/dharminpolra/Downloads/archive (1)/test.csv')
df.dtypes
# Out:
# City                     object
# Month                    object
# Year                      int64
# Decibel_Level             int64
# Traffic_Density          object
# Green_Space_Area          int64
# Air_Quality_Index         int64
# Happiness_Score         float64
# Cost_of_Living_Index      int64
# Healthcare_Index          int64
# dtype: object

# %%
df.head()
# Out:
#         City    Month  Year  Decibel_Level Traffic_Density  Green_Space_Area  \
# 0   Auckland  January  2030             55             Low                80
# 1     Berlin  January  2030             50             Low                60
# 2      Cairo  January  2030             75       Very High                15
# 3     Denver  January  2030             60          Medium                40
# 4  Edinburgh  January  2030             55             Low                65
#
#    Air_Quality_Index  Happiness_Score  Cost_of_Living_Index  Healthcare_Index
# 0                 40              8.4                   110                97
# 1                 45              7.9                    80                93
# 2                110              4.1                    55                69
# 3                 50              7.5                    95                89
# 4                 55              7.8                    85                92

# %%
df2=pd.read_csv('/Users/dharminpolra/Downloads/archive (1)/train.csv')
df2.head()
df2.dtypes
# Out:
# City                     object
# Month                    object
# Year                      int64
# Decibel_Level             int64
# Traffic_Density          object
# Green_Space_Area          int64
# Air_Quality_Index         int64
# Happiness_Score         float64
# Cost_of_Living_Index      int64
# Healthcare_Index          int64
# dtype: object

# %%
df.sort_values(by='Happiness_Score',ascending=False)
# Out:
#               City      Month  Year  Decibel_Level Traffic_Density  \
# 14            Oslo      March  2030             55             Low
# 21          Vienna        May  2030             60             Low
# 7         Helsinki   February  2030             60             Low
# 0         Auckland    January  2030             55             Low
# 47      Wellington  September  2030             55             Low
# 18          Sydney      April  2030             60             Low
# 25          Zurich        May  2030             55             Low
# 6           Geneva   February  2030             55             Low
# 31      Gothenburg       June  2030             60             Low
# 44         Tallinn     August  2030             55             Low
# 33       Innsbruck       July  2030             55             Low
# 1           Berlin    January  2030             50             Low
# 26        Adelaide       June  2030             60             Low
# ...

# %%
df2.sort_values(by='Happiness_Score',ascending=False)
# Out:
#                  City      Month  Year  Decibel_Level Traffic_Density  \
# 80             Napier     August  2024             55             Low
# 33               Oslo      April  2024             50             Low
# 84   Palmerston North  September  2024             55             Low
# 79             Nelson     August  2024             50             Low
# 34           Helsinki      April  2024             55             Low
# ..                ...        ...   ...            ...             ...
# 540         St Arnaud   November  2029             55             Low
# 541         Murchison   December  2029             60          Medium
# 542           Reefton   December  2029             55             Low
# 543         Greymouth   December  2029             50             Low
# 544          Hokitika   December  2029             55             Low
#
#      Green_Space_Area  Air_Quality_Index  Happiness_Score  \
# 80                105                  5              8.6
# ...

# %%
import matplotlib.pyplot as plt
sdf=df.sort_values(by='Happiness_Score',ascending=False)
plt.figure(figsize=(15,6))
plt.bar(sdf['City'],sdf['Happiness_Score'], width=0.6)
plt.xticks(rotation=60,ha='right')
plt.ylabel('Happyiness Score')
plt.xlabel('City')
plt.title('City by Happiness Score')

plt.tight_layout()
plt.show()
